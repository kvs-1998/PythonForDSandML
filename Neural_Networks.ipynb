# %% [markdown]
# <a href="https://colab.research.google.com/github/kvs1998/PythonForDSandML/blob/master/Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neural Networks are based on a single perceptron model. It based on a real biological neuron.
#
#
# 1.   Dendrites - input signal
# 2.   Nucleus - Calculation part
# 3.   Axon - output (which can imput to dendrite of another neuron)
#
#
#
#
# ![artificial-neural-network2.png](data:image/png;base64,...)

# %% [markdown]
# y = w1x1 + w2x2 + b
#
# b is for bias
#
# w1 and w2 are adjustable weights
#
# Neural Network (Multi-perseptron model)
#
# All the info goes from input to output layer. Single perceptron is the same thing as neuron. First layer is input layer. Last layer is known as the output layer(can be more than only one layer). All the layers in between are called hidden layers

# %% [markdown]
# *Multiclass Activation functions*
#
#
#
# 1.   Non-exclusive class
# 2.   Mutually Exclusive Class
